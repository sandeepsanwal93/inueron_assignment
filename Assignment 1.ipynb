# %% [markdown]
# ### 1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.

# %% [markdown]
# ####   *                 Expression
# ####  'hello'         Values
# ####   -87.8          Values
# ####     -                 Expression
# ####     /                 Expression
# ####    +	            Expression
# ####    6                Integer

# %% [markdown]
# ### 2. What is the difference between string and variable?

# %% [markdown]
# #### Variable use to store any values , For E.g: N=100  N is a variable which sotres integer value  and string is a value which is inside either single quote or double quote, e.g.: x="sandeep" or x='sandeep' , here sandeep is string.

# %% [markdown]
# ### 3. Describe three different data types.

# %% [markdown]
# ####  1.  int : it contain positive or negative no. without decimal (23,-56,78,-10)
# ####   2. String: it is a collection of character put under single quote or double quote and represent by str class.(e.g 'sandeep' , "sandeep")
# #### 3.   Boolean: it contains True or False values , denoted by class bool
# ####       Note – True and False with capital ‘T’ and ‘F’ are valid booleans otherwise python will give an error.

# %% [markdown]
# ### 4. What is an expression made up of? What do all expressions do?

# %% [markdown]
# #### An expression is a where we use variable , operator and methods to all together , If we are instructing  Python to print an expression, then the  interpreter evaluates an  expression and displays the output.. e.g: print(5+5).

# %% [markdown]
# ### 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?

# %% [markdown]
# #### An expression estimates  a single value. A statement can not evaluate .

# %% [markdown]
# ### 6. After running the following code, what does the variable bacon contain?
# ### bacon = 22
# ### bacon + 1

# %% [markdown]
# ####  Bacon+1 will not reassign the value in bacon

# %% [markdown]
# ### 7. What should the values of the following two terms be?
# ### 'spam' + 'spamspam'
# ### 'spam' * 3

# %% [markdown]
# #### both will give the output  'spamspamspam'

# %% [markdown]
# ### 8. Why is eggs a valid variable name while 100 is invalid?

# %% [markdown]
# ####  we can not use no. as a variable name it will give an error:  cannot assign to literal

# %% [markdown]
# ### 9. What three functions can be used to get the integer, floating-point number, or string version of a value?

# %% [markdown]
# ####   int(), float(), and str() functions

# %% [markdown]
# ### 10. Why does this expression cause an error? How can you fix it?
# ### 'I have eaten ' + 99 + ' burritos.'

# %% [markdown]
# ####  we can only concatenate str (not "int") to str , correct way is 'I have eaten ' + str(99) + ' burritos.
