# %% [markdown]
# ### Why are functions advantageous to have in your programs?

# %% [markdown]
# #### Functions reduce the rewriting of  code. This makes programs shorter, readable.

# %% [markdown]
# ### When does the code in a function run: when it&#39;s specified or when it&#39;s called?

# %% [markdown]
# #### when the function is called

# %% [markdown]
# ### What statement creates a function?

# %% [markdown]
# #### def statement

# %% [markdown]
# ### What is the difference between a function and a function call?

# %% [markdown]
# #### A function consists of the def statement and the code in its def clause.
#
# #### A function call is what moves the program execution into the function, and the function call evaluates to the function's return value

# %% [markdown]
# ### 5. How many global scopes are there in a Python program? How many local scopes?

# %% [markdown]
# #### one global scope and local scope is created when function called

# %% [markdown]
# ### What happens to variables in a local scope when the function call returns?

# %% [markdown]
# ####  local scope and all the variable it it are distroyed

# %% [markdown]
# ### What is the concept of a return value? Is it possible to have a return value in an expression?

# %% [markdown]
# #### return evaluate the value once function called , yes it is possible to have a return value in expression

# %% [markdown]
# ### If a function does not have a return statement, what is the return value of a call to that function?

# %% [markdown]
# #### return vale will be None

# %% [markdown]
# ### How do you make a function variable refer to the global variable?

# %% [markdown]
# #### by a global statement

# %% [markdown]
# ### What is the data type of None?

# %% [markdown]
# #### NoneType

# %% [markdown]
# #### What does the import areallyourpetsnamederic statement do?

# %% [markdown]
# ### this is not a python module

# %% [markdown]
# #### If you had a function named bacon() in a module named spam, how would you call it after importing spam?

# %% [markdown]
# ### spam.bacon()

# %% [markdown]
# ### What can you do to save a programme from crashing if it encounters an error?

# %% [markdown]
# #### by using try clause

# %% [markdown]
# ### What is the purpose of the try clause? What is the purpose of the except clause?

# %% [markdown]
# #### code which can get erro put in try and The code that executes if an error happens goes in the except.
